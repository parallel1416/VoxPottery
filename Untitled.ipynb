# %%
from g4f.gui import run_gui
run_gui()
# Out:
# Running on port 80
#  * Serving Flask app 'g4f.gui.server.app'
#  * Debug mode: off
# 以一种访问权限不允许的方式做了一个访问套接字的尝试。
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File D:\Python\Python310\lib\site-packages\werkzeug\serving.py:746, in BaseWSGIServer.__init__(self, host, port, app, handler, passthrough_errors, ssl_context, fd)
#     745 try:
# --> 746     self.server_bind()
#     747     self.server_activate()
#
# File D:\Python\Python310\lib\http\server.py:136, in HTTPServer.server_bind(self)
#     135 """Override server_bind to store the server name."""
# --> 136 socketserver.TCPServer.server_bind(self)
#     137 host, port = self.server_address[:2]
#
# File D:\Python\Python310\lib\socketserver.py:466, in TCPServer.server_bind(self)
#     465     self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# --> 466 self.socket.bind(self.server_address)
# ...

# %%
# !netstat -ano
# Out:
# 活动连接
#
#   协议  本地地址          外部地址        状态           PID
#   TCP    0.0.0.0:80             0.0.0.0:0              LISTENING       4
#   TCP    0.0.0.0:135            0.0.0.0:0              LISTENING       1740
#   TCP    0.0.0.0:445            0.0.0.0:0              LISTENING       4
#   TCP    0.0.0.0:5040           0.0.0.0:0              LISTENING       5460
#   TCP    0.0.0.0:49664          0.0.0.0:0              LISTENING       1432
#   TCP    0.0.0.0:49665          0.0.0.0:0              LISTENING       1244
#   TCP    0.0.0.0:49666          0.0.0.0:0              LISTENING       2284
#   TCP    0.0.0.0:49667          0.0.0.0:0              LISTENING       3552
#   TCP    0.0.0.0:49668          0.0.0.0:0              LISTENING       6180
#   TCP    0.0.0.0:49670          0.0.0.0:0              LISTENING       6732
#   TCP    0.0.0.0:49677          0.0.0.0:0              LISTENING       1328
#   TCP    0.0.0.0:62652          0.0.0.0:0              LISTENING       4580
# ...
